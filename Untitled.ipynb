# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt
from sodapy import Socrata 
from pprint import pprint

# %%
cdc_data = Socrata("data.cdc.gov", None)
cdc_results = cdc_data.get("n8mc-b4w4",limit=1000,res_state="MN")
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
cdc_df = pd.DataFrame.from_records(cdc_results)
cdc_df.head(150)
# Out:
#     case_month res_state state_fips_code  res_county county_fips_code  \
# 0      2020-04        MN              27      NOBLES            27105
# 1      2020-05        MN              27     STEARNS            27145
# 2      2021-08        MN              27     OLMSTED            27109
# 3      2021-11        MN              27    NICOLLET            27103
# 4      2020-10        MN              27     CHISAGO            27025
# ..         ...       ...             ...         ...              ...
# 145    2020-05        MN              27     STEARNS            27145
# 146    2021-08        MN              27     OLMSTED            27109
# 147    2021-11        MN              27    NICOLLET            27103
# 148    2020-10        MN              27     CHISAGO            27025
# 149    2022-01        MN              27  WASHINGTON            27163
#
#           age_group     sex     race        ethnicity case_positive_specimen  \
# ...

# %%
county_df = cdc_df['res_county'].unique()
county_df
# Out:
# array(['NOBLES', 'STEARNS', 'OLMSTED', 'NICOLLET', 'CHISAGO',
#        'WASHINGTON', 'MEEKER', 'KANDIYOHI', 'DODGE', 'CASS', 'GOODHUE',
#        'FREEBORN', 'BECKER', 'WABASHA', 'SHERBURNE', 'BROWN', 'ITASCA',
#        'STEELE', 'BELTRAMI', 'MOWER', 'MCLEOD', 'ISANTI', 'MILLE LACS',
#        'RAMSEY', 'POLK', 'PINE', 'RICE', 'DAKOTA', 'DOUGLAS', 'FILLMORE',
#        'CARLTON', 'MORRISON', 'BENTON', 'CLAY', 'HUBBARD', 'WINONA',
#        'CROW WING', 'OTTER TAIL', 'WRIGHT', 'HENNEPIN', 'CARVER', 'ANOKA',
#        'SCOTT', 'LYON', 'TODD', 'ST. LOUIS', 'BLUE EARTH', 'LE SUEUR'],
#       dtype=object)
