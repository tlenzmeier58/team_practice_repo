# %%
import requests
import os
import numpy as np
import pandas as pd
from sodapy import Socrata
from pprint import pprint

# %%
client = Socrata("data.cdc.gov", None)

results = client.get("n8mc-b4w4", limit=2000, res_state="MN")
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
results_df = pd.DataFrame.from_records(results)
results_df.head(100)
# Out:
#    case_month res_state state_fips_code res_county county_fips_code  \
# 0     2020-04        MN              27     NOBLES            27105
# 1     2020-05        MN              27    STEARNS            27145
# 2     2021-08        MN              27    OLMSTED            27109
# 3     2021-11        MN              27   NICOLLET            27103
# 4     2020-10        MN              27    CHISAGO            27025
# ..        ...       ...             ...        ...              ...
# 95    2020-11        MN              27   LE SUEUR            27079
# 96    2020-04        MN              27     NOBLES            27105
# 97    2020-05        MN              27    STEARNS            27145
# 98    2021-08        MN              27    OLMSTED            27109
# 99    2021-11        MN              27   NICOLLET            27103
#
#          age_group     sex     race        ethnicity case_positive_specimen  \
# 0   18 to 49 years  Female    White  Hispanic/Latino                      0
# 1   18 to 49 years  Female    White  Hispanic/Latino                      0
# 2     0 - 17 years    Male    White  Hispanic/Latino                      0
# 3     0 - 17 years  Female  Unknown          Missing                      0
# 4   18 to 49 years    Male    Black          Missing                      0
# ..             ...     ...      ...              ...                    ...
# 95  18 to 49 years    Male    White          Missing                      0
# 96  18 to 49 years  Female    White  Hispanic/Latino                      1
# 97  18 to 49 years  Female    White  Hispanic/Latino                      0
# 98    0 - 17 years    Male    White  Hispanic/Latino                      0
# 99    0 - 17 years  Female  Unknown          Missing                      0
#
#    case_onset_interval  process exposure_yn             current_status  \
# 0                    0  Missing         Yes  Laboratory-confirmed case
# 1                    0  Missing         Yes  Laboratory-confirmed case
# 2                  NaN  Missing     Missing  Laboratory-confirmed case
# 3                  NaN  Missing     Missing  Laboratory-confirmed case
# 4                  NaN  Missing         Yes  Laboratory-confirmed case
# ..                 ...      ...         ...                        ...
# 95                 NaN  Missing     Missing  Laboratory-confirmed case
# 96                   0  Missing         Yes  Laboratory-confirmed case
# 97                   0  Missing     Missing  Laboratory-confirmed case
# 98                   0  Missing         Yes  Laboratory-confirmed case
# 99                 NaN  Missing     Missing  Laboratory-confirmed case
#
#    symptom_status  hosp_yn   icu_yn death_yn underlying_conditions_yn
# 0     Symptomatic      Yes       No       No                      NaN
# 1     Symptomatic  Missing  Missing       No                      Yes
# 2         Missing  Missing  Missing       No                      NaN
# 3         Missing  Missing  Missing       No                      NaN
# 4         Missing  Missing  Missing       No                      NaN
# ..            ...      ...      ...      ...                      ...
# 95        Missing  Missing  Missing       No                      NaN
# 96    Symptomatic      Yes       No       No                      NaN
# 97    Symptomatic  Missing  Missing       No                      Yes
# 98    Symptomatic       No  Missing       No                      NaN
# 99        Missing  Missing  Missing       No                      NaN
#
# [100 rows x 19 columns]

# %%
# cdc_url = "https://data.cdc.gov/resource/n8mc-b4w4.json?res_state=MN"
# response = requests.get(cdc_url)
# response_json = response.json()

# print(response.status_code)
# pprint(response_json)
# len(response_json)
# Out:
# 1000
