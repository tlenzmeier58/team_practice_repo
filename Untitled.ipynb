# %%
import requests
import os
import numpy as np
import pandas as pd
from sodapy import Socrata
from pprint import pprint
import matplotlib.pyplot as plt
import scipy.stats as st
from scipy.stats import linregress
import numpy as np

# %%
client = Socrata("data.cdc.gov", None)

results = client.get("n8mc-b4w4", limit = 150000, res_state="MN")
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
results_df = pd.DataFrame.from_records(results)
results_df.head(15)
# Out:
#    case_month res_state state_fips_code  res_county county_fips_code  \
# 0     2020-04        MN              27      NOBLES            27105
# 1     2020-05        MN              27     STEARNS            27145
# 2     2021-08        MN              27     OLMSTED            27109
# 3     2021-11        MN              27    NICOLLET            27103
# 4     2020-10        MN              27     CHISAGO            27025
# 5     2022-01        MN              27  WASHINGTON            27163
# 6     2020-11        MN              27      MEEKER            27093
# 7     2021-10        MN              27   KANDIYOHI            27067
# 8     2020-12        MN              27       DODGE            27039
# 9     2020-11        MN              27        CASS            27021
# 10    2020-11        MN              27     GOODHUE            27049
# 11    2021-12        MN              27    FREEBORN            27047
# 12    2021-11        MN              27      BECKER            27005
# ...

# %%
# results_df.to_csv("cdc_test.csv")

# %%
results_df.columns
# Out:
# Index(['case_month', 'res_state', 'state_fips_code', 'res_county',
#        'county_fips_code', 'age_group', 'sex', 'race', 'ethnicity',
#        'case_positive_specimen', 'case_onset_interval', 'process',
#        'exposure_yn', 'current_status', 'symptom_status', 'hosp_yn', 'icu_yn',
#        'death_yn', 'underlying_conditions_yn'],
#       dtype='object')

# %%
results_df['state_fips_code'].unique()
# Out:
# array(['27'], dtype=object)

# %%
results_df['ethnicity'].unique()
# Out:
# array(['Hispanic/Latino', 'Missing', 'NA', 'Non-Hispanic/Latino',
#        'Unknown'], dtype=object)

# %%
race_groups = results_df.groupby(["race"])
race_groups.head(15)
# Out:
#      case_month res_state state_fips_code res_county county_fips_code  \
# 0       2020-04        MN              27     NOBLES            27105
# 1       2020-05        MN              27    STEARNS            27145
# 2       2021-08        MN              27    OLMSTED            27109
# 3       2021-11        MN              27   NICOLLET            27103
# 4       2020-10        MN              27    CHISAGO            27025
# ...         ...       ...             ...        ...              ...
# 4838    2020-12        MN              27   BELTRAMI            27007
# 4887    2020-12        MN              27   BELTRAMI            27007
# 4935    2020-12        MN              27   BELTRAMI            27007
# 4983    2020-12        MN              27   BELTRAMI            27007
# 5032    2020-12        MN              27   BELTRAMI            27007
#
#            age_group     sex                           race  \
# 0     18 to 49 years  Female                          White
# ...

# %%
race_groups['race'].unique()
# Out:
# race
# American Indian/Alaska Native    [American Indian/Alaska Native]
# Asian                                                    [Asian]
# Black                                                    [Black]
# Multiple/Other                                  [Multiple/Other]
# NA                                                          [NA]
# Unknown                                                [Unknown]
# White                                                    [White]
# Name: race, dtype: object

# %%
# _groups = clean_mouse_study.groupby(["Drug Regimen"])
# drug_groups.head()
